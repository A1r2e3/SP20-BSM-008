# %%
import numpy as np
f = lambda x: 0.1*x**5-0.2*x**3+0.1*x-0.2
x= 0.1
h= 0.1
dff1= 0.09405
dff2 = -0.118
print("f'(x)err f''(x)err")
# Out:
# f'(x)err f''(x)err

# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: 0.1*x**5-0.2*x**3+0.1*x-0.2
h=0.01
x= np.linspace(-1,1,50)
dff1= (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot (x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: 0.1*x**5-0.2*x**3+0.1*x-0.2
h=0.05
x= np.linspace(3,-3,50)
dff1= (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot (x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: 0.1*x**8-0.2*x**6+0.1*x-0.2
h=0.1
x= np.linspace(5,6,100)
dff1= (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot (x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: 0.1*x-0.2*x**2+0.1*x-0.11
h=0.01
x= np.linspace(0,3,75)
dff1= (f(x+h)-f(x-h))/(2*h)
dff2= (f(x+h)-2*f(x)+f(x-h))/h**2
plt.plot (x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()
